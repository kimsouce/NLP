# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ln -s /content/drive/My\ Drive/ /my\drive
# Out:
# ln: failed to create symbolic link '/mydrive/My Drive': Operation not supported

# %%
import os
import re

import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# 데이터 전처리

# %%
RANDOM_SEED = 42
TEST_SPLIT = 0.2

# %%
train_data = pd.read_csv('/content/drive/My Drive/딥러닝 실습/data_in/train_clean.csv')
train_data.head()
# Out:
#                                               review  sentiment
# 0  stuff going moment mj started listening music ...          1
# 1  classic war worlds timothy hines entertaining ...          1
# 2  film starts manager nicholas bell giving welco...          0
# 3  must assumed praised film greatest filmed oper...          0
# 4  superbly trashy wondrously unpretentious explo...          1

# %%
reviews = list(train_data['review'])
sentiments = list(train_data['sentiment'])

# %%
sentences = []
for review in reviews:
  sentences.append(review.split()) #split 함수를 사용해서 띄어쓰기 기준으로 구분

# %% [markdown]
# Word2Vec 모델 학습 진행

# %%
num_features = 300 #각 단어에 대해 임베딩된 벡터의 차원을 정한다.
min_word_count = 10 #9번 이하로 나온 단어들은 학습하지 않는다.
num_workers = 4 #모델 학습 시 학습을 위한 프로세스 개수를 지정한다. 
context = 10 #Window크기
downsampling = 1e-3 #빠른 학습을 위해 정답 단어 라벨에 대한 다운샘플링 비율을 지정. 보통 0.001이 좋은 성능이다.

# %%
import logging #word2vec 학습의 과정에서 진행 상황을 확인한다. 
logging.basicConfig(format ='%(asctime)s: %(levelname)s: %(message)s',level=logging.INFO)

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (2.0.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.12.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.18.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.23.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (1.14.9)
# Requirement already satisfied: boto in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.49.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2020.6.20)
# Requirement already satisfied: botocore<1.18.0,>=1.17.9 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (1.17.9)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.3.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.9->boto3->smart-open>=1.2.1->gensim) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.9->boto3->smart-open>=1.2.1->gensim) (0.15.2)

# %%
from gensim.models import word2vec
model = word2vec.Word2Vec(sentences, workers=num_workers, size=num_features, min_count = min_word_count, window = context, sample = downsampling)
# Out:
# 2020-07-13 06:23:32,456: INFO: 'pattern' package not found; tag filters are not available for English
# 2020-07-13 06:23:32,461: INFO: collecting all words and their counts
# 2020-07-13 06:23:32,462: INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-07-13 06:23:32,762: INFO: PROGRESS: at sentence #10000, processed 1205223 words, keeping 51374 word types
# 2020-07-13 06:23:33,068: INFO: PROGRESS: at sentence #20000, processed 2396605 words, keeping 67660 word types
# 2020-07-13 06:23:33,224: INFO: collected 74065 word types from a corpus of 2988089 raw words and 25000 sentences
# 2020-07-13 06:23:33,225: INFO: Loading a fresh vocabulary
# 2020-07-13 06:23:33,285: INFO: effective_min_count=10 retains 19717 unique words (26% of original 74065, drops 54348)
# 2020-07-13 06:23:33,286: INFO: effective_min_count=10 leaves 2854211 word corpus (95% of original 2988089, drops 133878)
# 2020-07-13 06:23:33,351: INFO: deleting the raw counts dictionary of 74065 items
# 2020-07-13 06:23:33,353: INFO: sample=0.001 downsamples 24 most-common words
# 2020-07-13 06:23:33,354: INFO: downsampling leaves estimated 2733350 word corpus (95.8% of prior 2854211)
# 2020-07-13 06:23:33,426: INFO: estimated required memory for 19717 words and 300 dimensions: 57179300 bytes
# 2020-07-13 06:23:33,427: INFO: resetting layer weights
# 2020-07-13 06:23:37,365: INFO: training model with 4 workers on 19717 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2020-07-13 06:23:38,406: INFO: EPOCH 1 - PROGRESS: at 10.90% examples, 289856 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:39,420: INFO: EPOCH 1 - PROGRESS: at 21.50% examples, 292373 words/s, in_qsize 8, out_qsize 1
# 2020-07-13 06:23:40,468: INFO: EPOCH 1 - PROGRESS: at 33.15% examples, 296013 words/s, in_qsize 6, out_qsize 1
# 2020-07-13 06:23:41,471: INFO: EPOCH 1 - PROGRESS: at 44.45% examples, 298716 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:42,480: INFO: EPOCH 1 - PROGRESS: at 54.91% examples, 296593 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:43,520: INFO: EPOCH 1 - PROGRESS: at 66.38% examples, 296763 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:44,521: INFO: EPOCH 1 - PROGRESS: at 77.34% examples, 297054 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:45,543: INFO: EPOCH 1 - PROGRESS: at 87.86% examples, 295421 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:46,462: INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-07-13 06:23:46,490: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-07-13 06:23:46,513: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-07-13 06:23:46,514: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-07-13 06:23:46,515: INFO: EPOCH - 1 : training on 2988089 raw words (2733484 effective words) took 9.1s, 299000 effective words/s
# 2020-07-13 06:23:47,537: INFO: EPOCH 2 - PROGRESS: at 10.90% examples, 295556 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:48,584: INFO: EPOCH 2 - PROGRESS: at 21.50% examples, 290421 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:49,591: INFO: EPOCH 2 - PROGRESS: at 33.15% examples, 298624 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:50,632: INFO: EPOCH 2 - PROGRESS: at 44.11% examples, 295791 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:51,635: INFO: EPOCH 2 - PROGRESS: at 55.23% examples, 298142 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:52,647: INFO: EPOCH 2 - PROGRESS: at 66.74% examples, 299356 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:53,649: INFO: EPOCH 2 - PROGRESS: at 77.68% examples, 299283 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:54,710: INFO: EPOCH 2 - PROGRESS: at 89.32% examples, 299719 words/s, in_qsize 7, out_qsize 1
# 2020-07-13 06:23:55,589: INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-07-13 06:23:55,603: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-07-13 06:23:55,612: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-07-13 06:23:55,616: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-07-13 06:23:55,617: INFO: EPOCH - 2 : training on 2988089 raw words (2733449 effective words) took 9.1s, 300587 effective words/s
# 2020-07-13 06:23:56,628: INFO: EPOCH 3 - PROGRESS: at 10.90% examples, 298432 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:57,668: INFO: EPOCH 3 - PROGRESS: at 21.50% examples, 292830 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:58,726: INFO: EPOCH 3 - PROGRESS: at 33.49% examples, 298186 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:23:59,730: INFO: EPOCH 3 - PROGRESS: at 44.46% examples, 298224 words/s, in_qsize 7, out_qsize 1
# 2020-07-13 06:24:00,754: INFO: EPOCH 3 - PROGRESS: at 55.57% examples, 299264 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:01,770: INFO: EPOCH 3 - PROGRESS: at 67.07% examples, 299700 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:02,797: INFO: EPOCH 3 - PROGRESS: at 78.35% examples, 299780 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:03,813: INFO: EPOCH 3 - PROGRESS: at 89.69% examples, 300245 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:04,638: INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-07-13 06:24:04,654: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-07-13 06:24:04,662: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-07-13 06:24:04,680: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-07-13 06:24:04,681: INFO: EPOCH - 3 : training on 2988089 raw words (2732988 effective words) took 9.1s, 301747 effective words/s
# 2020-07-13 06:24:05,721: INFO: EPOCH 4 - PROGRESS: at 10.53% examples, 281120 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:06,739: INFO: EPOCH 4 - PROGRESS: at 21.50% examples, 291732 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:07,752: INFO: EPOCH 4 - PROGRESS: at 32.49% examples, 293011 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:08,794: INFO: EPOCH 4 - PROGRESS: at 44.11% examples, 295961 words/s, in_qsize 8, out_qsize 0
# 2020-07-13 06:24:09,889: INFO: EPOCH 4 - PROGRESS: at 55.90% examples, 296499 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:10,911: INFO: EPOCH 4 - PROGRESS: at 67.42% examples, 297494 words/s, in_qsize 7, out_qsize 1
# 2020-07-13 06:24:11,927: INFO: EPOCH 4 - PROGRESS: at 78.70% examples, 298362 words/s, in_qsize 8, out_qsize 1
# 2020-07-13 06:24:13,016: INFO: EPOCH 4 - PROGRESS: at 90.68% examples, 298526 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:13,758: INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-07-13 06:24:13,773: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-07-13 06:24:13,781: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-07-13 06:24:13,786: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-07-13 06:24:13,787: INFO: EPOCH - 4 : training on 2988089 raw words (2733223 effective words) took 9.1s, 300385 effective words/s
# 2020-07-13 06:24:14,864: INFO: EPOCH 5 - PROGRESS: at 10.90% examples, 280090 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:15,965: INFO: EPOCH 5 - PROGRESS: at 22.52% examples, 288160 words/s, in_qsize 6, out_qsize 1
# 2020-07-13 06:24:16,966: INFO: EPOCH 5 - PROGRESS: at 33.49% examples, 291601 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:17,975: INFO: EPOCH 5 - PROGRESS: at 44.45% examples, 292863 words/s, in_qsize 6, out_qsize 1
# 2020-07-13 06:24:18,986: INFO: EPOCH 5 - PROGRESS: at 55.25% examples, 293558 words/s, in_qsize 8, out_qsize 1
# 2020-07-13 06:24:20,000: INFO: EPOCH 5 - PROGRESS: at 67.07% examples, 296832 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:21,008: INFO: EPOCH 5 - PROGRESS: at 78.04% examples, 296877 words/s, in_qsize 7, out_qsize 0
# 2020-07-13 06:24:22,033: INFO: EPOCH 5 - PROGRESS: at 89.32% examples, 297363 words/s, in_qsize 8, out_qsize 0
# 2020-07-13 06:24:22,860: INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-07-13 06:24:22,875: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-07-13 06:24:22,915: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-07-13 06:24:22,925: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-07-13 06:24:22,925: INFO: EPOCH - 5 : training on 2988089 raw words (2733525 effective words) took 9.1s, 299360 effective words/s
# 2020-07-13 06:24:22,926: INFO: training on a 14940445 raw words (13666669 effective words) took 45.6s, 299971 effective words/s

# %%
def get_features(words, model, num_features):
  feature_vector = np.zeros((num_features), dtype=np.float32)

  num_words = 0
  index2word_set = set(model.wv.index2word)

  for w in words:
     if w in index2word_set:
       num_words +=1
       feature_vector = np.add(feature_vector, model[w])
  
  feature_vector = np.divide(feature_vector, num_words)
  return feature_vector

# %%
def get_dataset(reviews, model, num_features):
  dataset = list()

  for s in reviews:
    dataset.append(get_features(s,model,num_features))

  reviewFeatureVecs = np.stack(dataset)

  return reviewFeatureVecs

# %%
import sys
python_version = sys.version_info[0]

# %%
# If you're running on Colab, you'll need to install the What-if Tool package and authenticate
# If you're on Cloud AI Platform Notebooks, you'll need to install XGBoost on the TF instance
def pip_install(module):
    if python_version == '2':
        # !pip install {module} --quiet
    else:
        # !pip3 install {module} --quiet

try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
    pip_install('witwidget')

    from google.colab import auth
    auth.authenticate_user()
else:
    pip_install('xgboost')

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
xgb = XGBClassifier(n_estimators = 100, n_jobs = -1, random_state = 2018)

X= get_dataset(sentences, model, num_features)
y= np.array(sentiments)


# %time xgb = xgb.fit(X,y)
# %time score = np.mean(cross_val_score(xgb, X, y, cv=10, scoring='roc_auc',verbose=5))

score
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.
# CPU times: user 1min 22s, sys: 130 ms, total: 1min 22s
# Wall time: 41.7 s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................................... , score=0.920, total=  37.8s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   37.8s remaining:    0.0s
# [CV] .................................... , score=0.921, total=  39.7s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.3min remaining:    0.0s
# [CV] .................................... , score=0.930, total=  38.5s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  1.9min remaining:    0.0s
# [CV] .................................... , score=0.916, total=  38.6s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.6min remaining:    0.0s
# [CV] .................................... , score=0.919, total=  38.4s
# [CV]  ................................................................
# [CV] .................................... , score=0.915, total=  38.4s
# [CV]  ................................................................
# [CV] .................................... , score=0.917, total=  38.7s
# [CV]  ................................................................
# [CV] .................................... , score=0.929, total=  39.4s
# [CV]  ................................................................
# [CV] .................................... , score=0.907, total=  38.5s
# [CV]  ................................................................
# [CV] .................................... , score=0.917, total=  38.6s
# CPU times: user 12min 41s, sys: 420 ms, total: 12min 42s
# Wall time: 6min 26s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  6.4min finished
# 0.9189764479999999

# %%
test_data = pd.read_csv('/content/drive/My Drive/딥러닝 실습/data_in/test_clean.csv')

test_review = list(test_data['review'])

# %%
test_sentences = list()
for review in test_review:
  test_sentences.append(review.split())

# %%
test_data_vecs1 = get_dataset(test_sentences, model, num_features) #X_test
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.

# %%
test_predicted = xgb.predict(test_data_vecs1)

# %%
ids = list(test_data['id'])

# %%
answer_dataset = pd.DataFrame({'id': ids, 'sentiment': test_predicted})

# %%
if not os.path.exists('/content/drive/My Drive/딥러닝 실습/data_out'):
  os.makedirs('/content/drive/My Drive/딥러닝 실습/data_out')

answer_dataset.to_csv('/content/drive/My Drive/딥러닝 실습/data_out' + 'xgb_w2v_answer.csv', index=False, quoting=3)
